# %%
import pandas as pd

# %%
#for reading excel file using pandas by default it reads first sheet in your excel file
pd.read_excel(r'C:\Users\MIET\Downloads\fsds\Attribute DataSet.xlsx')
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
df=pd.read_excel(r'C:\Users\MIET\Downloads\fsds\Attribute DataSet.xlsx')
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#for reading customize sheet in excel file
pd.read_excel(r'C:\Users\MIET\Downloads\fsds\Attribute DataSet.xlsx',sheet_name="arun")
# Out:
#             0        1
# 0          af      ddd
# 1    fdfdjggj    ddfgg
# 2  dg;sfgs'fl    ddfgg
# 3         afa  ffdfdff
# 4   fdsgdsgvc      dff
# 5        cvcv      NaN

# %%
#default header is first row of excel seat.
#set Haeder 
pd.read_excel(r'C:\Users\MIET\Downloads\fsds\Attribute DataSet.xlsx',sheet_name="arun",header=None,names=["A","B"])
# Out:
#             A        B
# 0          af      ddd
# 1    fdfdjggj    ddfgg
# 2  dg;sfgs'fl    ddfgg
# 3         afa  ffdfdff
# 4   fdsgdsgvc      dff
# 5        cvcv      NaN

# %%
df=pd.read_excel(r'C:\Users\MIET\Downloads\fsds\Attribute DataSet.xlsx')

# %%
#only two value from head side(upperside )
df.head(2)
# Out:
#      Dress_ID   Style Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852    Sexy   Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089  Casual   Low     0.0    L  Summer   o-neck        Petal
#
#   waiseline    Material FabricType Decoration Pattern Type  Recommendation
# 0    empire         NaN    chiffon    ruffles       animal               1
# 1   natural  microfiber        NaN    ruffles       animal               0

# %%
#value from bottom side
df.tail(4)
# Out:
#       Dress_ID   Style    Price  Rating  Size  Season   NeckLine SleeveLength  \
# 496  722565148    Sexy      Low     4.3  free  Summer     o-neck         full
# 497  532874347  Casual  Average     4.7     M  Summer     v-neck         full
# 498  655464934  Casual  Average     4.6     L  winter  boat-neck    sleevless
# 499  919930954  Casual      Low     4.4  free  Summer     v-neck        short
#
#     waiseline Material  FabricType Decoration Pattern Type  Recommendation
# 496    empire   cotton         NaN        NaN          NaN               0
# 497    empire   cotton         NaN       lace        solid               1
# 498    empire     silk  broadcloth   applique        print               1
# 499    empire   cotton    Corduroy       lace        solid               0

# %%
#by default it print first five value
df.head()
# Out:
#      Dress_ID    Style    Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0    L  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6    L  Spring   o-neck         full
# 4   876339541     cute      Low     4.5    M  Summer   o-neck    butterfly
#
#   waiseline       Material FabricType  Decoration Pattern Type  Recommendation
# 0    empire            NaN    chiffon     ruffles       animal               1
# 1   natural     microfiber        NaN     ruffles       animal               0
# 2   natural       polyster        NaN         NaN        print               0
# 3   natural           silk    chiffon  embroidary        print               1
# 4   natural  chiffonfabric    chiffon         bow          dot               0

# %%
df.tail()
# Out:
#       Dress_ID   Style    Price  Rating  Size  Season   NeckLine SleeveLength  \
# 495  713391965  Casual      Low     4.7     M  Spring     o-neck         full
# 496  722565148    Sexy      Low     4.3  free  Summer     o-neck         full
# 497  532874347  Casual  Average     4.7     M  Summer     v-neck         full
# 498  655464934  Casual  Average     4.6     L  winter  boat-neck    sleevless
# 499  919930954  Casual      Low     4.4  free  Summer     v-neck        short
#
#     waiseline  Material  FabricType Decoration Pattern Type  Recommendation
# 495   natural  polyster         NaN        NaN        solid               1
# 496    empire    cotton         NaN        NaN          NaN               0
# 497    empire    cotton         NaN       lace        solid               1
# 498    empire      silk  broadcloth   applique        print               1
# 499    empire    cotton    Corduroy       lace        solid               0

# %%
#read csv file
pd.read_csv(r"C:\Users\MIET\Downloads\fsds\haberman.csv",header=None,names=['Age' , " Patient's year of operation ", 'Number of positive' , 'Survival status'])
# Out:
#      Age   Patient's year of operation   Number of positive  Survival status
# 0     30                             64                   1                1
# 1     30                             62                   3                1
# 2     30                             65                   0                1
# 3     31                             59                   2                1
# 4     31                             65                   4                1
# ..   ...                            ...                 ...              ...
# 301   75                             62                   1                1
# 302   76                             67                   0                1
# 303   77                             65                   3                1
# 304   78                             65                   1                2
# 305   83                             58                   2                2
#
# [306 rows x 4 columns]

# %%
pd.read_csv(r"C:\Users\MIET\Downloads\fsds\haberman.csv")
# Out:
#      30  64   1  1.1
# 0    30  62   3    1
# 1    30  65   0    1
# 2    31  59   2    1
# 3    31  65   4    1
# 4    33  58  10    1
# ..   ..  ..  ..  ...
# 300  75  62   1    1
# 301  76  67   0    1
# 302  77  65   3    1
# 303  78  65   1    2
# 304  83  58   2    2
#
# [305 rows x 4 columns]

# %%
pd.read_csv(r"C:\Users\MIET\Downloads\fsds\haberman1.csv")
# Out:
#       30@64@1@1
# 0     30@62@3@1
# 1     30@65@0@1
# 2     31@59@2@1
# 3     31@65@4@1
# 4    33@58@10@1
# ..          ...
# 300   75@62@1@1
# 301   76@67@0@1
# 302   77@65@3@1
# 303   78@65@1@2
# 304   83@58@2@2
#
# [305 rows x 1 columns]

# %%
#remove @ in csv file. it is use in when data is seprated by something in place of comma.
pd.read_csv(r"C:\Users\MIET\Downloads\fsds\haberman1.csv",sep="@")
# Out:
#      30  64   1  1.1
# 0    30  62   3    1
# 1    30  65   0    1
# 2    31  59   2    1
# 3    31  65   4    1
# 4    33  58  10    1
# ..   ..  ..  ..  ...
# 300  75  62   1    1
# 301  76  67   0    1
# 302  77  65   3    1
# 303  78  65   1    2
# 304  83  58   2    2
#
# [305 rows x 4 columns]

# %%
#read csv file from url. go to github and click the csv file and click raw the copy url 
pd.read_csv("https://raw.githubusercontent.com/codeforamerica/ohana-api/master/data/sample-csv/addresses.csv")
# Out:
#     id  location_id                   address_1  address_2  \
# 0    1            1       2600 Middlefield Road        NaN
# 1    2            2            24 Second Avenue        NaN
# 2    3            3            24 Second Avenue        NaN
# 3    4            4            24 Second Avenue        NaN
# 4    5            5            24 Second Avenue        NaN
# 5    6            6           800 Middle Avenue        NaN
# 6    7            7              500 Arbor Road        NaN
# 7    8            8           800 Middle Avenue        NaN
# 8    9            9       2510 Middlefield Road        NaN
# 9   10           10       1044 Middlefield Road        NaN
# 10  11           11         2140 Euclid Avenue.        NaN
# 11  12           12       1044 Middlefield Road  2nd Floor
# 12  13           13         399 Marine Parkway.        NaN
# 13  14           14          660 Veterans Blvd.        NaN
# 14  15           15        1500 Valencia Street        NaN
# ...

# %%
#read html file
a=pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")
a
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
type(a)
# Out:
# list

# %%
len(a)
# Out:
# 1

# %%
a[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
js=pd.read_json('https://api.github.com/repos/pandas-dev/pandas/issues')

# %%
js
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
js.columns
# Out:
# Index(['url', 'repository_url', 'labels_url', 'comments_url', 'events_url',
#        'html_url', 'id', 'node_id', 'number', 'title', 'user', 'labels',
#        'state', 'locked', 'assignee', 'assignees', 'milestone', 'comments',
#        'created_at', 'updated_at', 'closed_at', 'author_association',
#        'active_lock_reason', 'draft', 'pull_request', 'body', 'reactions',
#        'timeline_url', 'performed_via_github_app', 'state_reason'],
#       dtype='object')

# %%
js['user'][0]
# Out:
# {'login': 'twoertwein',
#  'id': 6618166,
#  'node_id': 'MDQ6VXNlcjY2MTgxNjY=',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/6618166?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/twoertwein',
#  'html_url': 'https://github.com/twoertwein',
#  'followers_url': 'https://api.github.com/users/twoertwein/followers',
#  'following_url': 'https://api.github.com/users/twoertwein/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/twoertwein/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/twoertwein/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/twoertwein/subscriptions',
#  'organizations_url': 'https://api.github.com/users/twoertwein/orgs',
#  'repos_url': 'https://api.github.com/users/twoertwein/repos',
#  'events_url': 'https://api.github.com/users/twoertwein/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/twoertwein/received_events',
#  'type': 'User',
# ...

# %%
df=pd.read_excel(r'C:\Users\MIET\Downloads\fsds\Attribute DataSet.xlsx')
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
#to convert file into json format file and save 
df.to_json('random123.json')

# %%
pwd
# Out:
# 'C:\\Users\\MIET'

# %%
pd.read_json(r"C:\Users\MIET\random123.json")
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire           None     chiffon     ruffles
# ...

# %%
df.to_csv("randoncsv123.csv")

# %%
pd.read_csv(r"C:\Users\MIET\randoncsv123.csv")
# Out:
#      Unnamed: 0    Dress_ID    Style    Price  Rating  Size  Season  \
# 0             0  1006032852     Sexy      Low     4.6     M  Summer
# 1             1  1212192089   Casual      Low     0.0     L  Summer
# 2             2  1190380701  vintage     High     0.0     L  Automn
# 3             3   966005983    Brief  Average     4.6     L  Spring
# 4             4   876339541     cute      Low     4.5     M  Summer
# ..          ...         ...      ...      ...     ...   ...     ...
# 495         495   713391965   Casual      Low     4.7     M  Spring
# 496         496   722565148     Sexy      Low     4.3  free  Summer
# 497         497   532874347   Casual  Average     4.7     M  Summer
# 498         498   655464934   Casual  Average     4.6     L  winter
# 499         499   919930954   Casual      Low     4.4  free  Summer
#
#       NeckLine SleeveLength waiseline       Material  FabricType  Decoration  \
# ...

# %%
#for convert csv file with separtor
df.to_csv("randoncsv123.csv",sep="@")

# %%
pd.read_csv(r"C:\Users\MIET\randoncsv123.csv")
# Out:
#     @Dress_ID@Style@Price@Rating@Size@Season@NeckLine@SleeveLength@waiseline@Material@FabricType@Decoration@Pattern Type@Recommendation
# 0    0@1006032852@Sexy@Low@4.6@M@Summer@o-neck@slee...
# 1    1@1212192089@Casual@Low@0.0@L@Summer@o-neck@Pe...
# 2    2@1190380701@vintage@High@0.0@L@Automn@o-neck@...
# 3    3@966005983@Brief@Average@4.6@L@Spring@o-neck@...
# 4    4@876339541@cute@Low@4.5@M@Summer@o-neck@butte...
# ..                                                 ...
# 495  495@713391965@Casual@Low@4.7@M@Spring@o-neck@f...
# 496  496@722565148@Sexy@Low@4.3@free@Summer@o-neck@...
# 497  497@532874347@Casual@Average@4.7@M@Summer@v-ne...
# 498  498@655464934@Casual@Average@4.6@L@winter@boat...
# 499  499@919930954@Casual@Low@4.4@free@Summer@v-nec...
#
# [500 rows x 1 columns]

# %%
#to remove the row index inex=False used 
df.to_csv("randoncsv123.csv",index=False)

# %%
pd.read_csv(r"C:\Users\MIET\randoncsv123.csv")
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...
